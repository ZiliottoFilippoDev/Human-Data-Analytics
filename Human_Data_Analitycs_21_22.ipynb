# %% [markdown]
# # HDA Project 21/22
#
# Authors:
#  - Michele Maria Crudele
#  - Filippo Ziliotto
#
# This is the code implementede for the HDA course project.
#
# *All the notebook was run on Colab. The cells do not display the output have still been previously run

# %% [markdown]
# # Libraries

# %%
import keras
from matplotlib.transforms import Affine2D
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import RepeatedKFold
import statistics
import pandas as pd
import seaborn as sns
import os
import cv2
from IPython.display import Image
from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from sklearn.utils import shuffle
from keras.layers import Dense, Conv2D,TimeDistributed,Dropout,Layer,Normalization
from keras.layers import MaxPooling2D, Flatten, BatchNormalization,Concatenate,GlobalAveragePooling2D
from keras.layers import SimpleRNN, LSTM
from sklearn.metrics import confusion_matrix
from matplotlib.pyplot import figure
from sklearn.model_selection import KFold,StratifiedKFold, LeaveOneOut,LeaveOneGroupOut
from keras import Input, Model
from scipy import stats, ndimage, misc
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from sklearn.metrics import classification_report
import random
from keras import backend as K
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Functions

# %%
def read_experiment_1_17(directory="experiment-i/"):
    li = []

    for root, subdirectories, files in os.walk(directory):
        for file in files:
            if file.endswith('.txt'):
                data = pd.read_csv(os.path.join(root, file),encoding='utf-8',sep='',delimiter='\t',
                               keep_default_na=False,header=None, skiprows=3)
                data.drop(data.columns[len(data.columns)-1], axis=1, inplace=True)
                data = data.iloc[:-3,:]
                data['posture'] = int(str(file)[:-4])
                data['subject'] = str(root[-2:])
                li.append(data)
            else:
                continue
        
    frames = pd.concat(li, axis=0, ignore_index=True)
    return frames

def read_experiment_1_3(directory="experiment-i/"):

    li = []
    for root, subdirectories, files in os.walk(directory):
        for file in files:
            if file.endswith('.txt'):
                if file == '1.txt' or file == '8.txt' or file == '9.txt' or file == '10.txt' or file == '11.txt' or file == '12.txt' or file == '15.txt' or file == '16.txt' or file == '17.txt':
                    data = pd.read_csv(os.path.join(root, file),encoding='utf-8',sep='',delimiter='\t',keep_default_na=False,header=None,skiprows=3)
                    data.drop(data.columns[len(data.columns)-1], axis=1, inplace=True)
                    data = data.iloc[:-3,:]
                    data['posture'] = str(1)
                    data['subject'] = str(root[-2:])
                    li.append(data)
                if file == '3.txt' or file == '6.txt' or file == '7.txt' or file == '14.txt':
                    data = pd.read_csv(os.path.join(root, file),encoding='utf-8',sep='',delimiter='\t',keep_default_na=False,header=None,skiprows=3)
                    data.drop(data.columns[len(data.columns)-1], axis=1, inplace=True)
                    data = data.iloc[:-3,:]
                    data['posture'] = str(2)
                    data['subject'] = str(root[-2:])
                    li.append(data)
                if file == '2.txt' or file == '4.txt' or file == '5.txt' or file == '13.txt':          
                    data = pd.read_csv(os.path.join(root, file),encoding='utf-8',sep='',delimiter='\t',keep_default_na=False,header=None,skiprows=3)
                    data.drop(data.columns[len(data.columns)-1], axis=1, inplace=True)
                    data = data.iloc[:-3,:]
                    data['posture'] = str(3)
                    data['subject'] = str(root[-2:])
                    li.append(data)
            else:
                continue
        
    frames = pd.concat(li, axis=0, ignore_index=True)
    return frames

def preprocess(dataframe, test_size):
    
    x = frames.iloc[:,:-2].values.reshape(len(frames),64,32,1)
    x = ndimage.median_filter(x, 3) 
    norm = lambda s: s/1000            #1000 is the maximum value of the pressure on the sensors
    x = np.array([norm(xx) for xx in x])

    y_pos = frames.iloc[:,-2].values
    y_pos = pd.get_dummies(frames['posture']).values

    y_sub = frames.iloc[:,-1].values
    y_sub = pd.get_dummies(frames['subject']).values
    
    X_train,X_test,y_train_pos,y_test_pos,y_train_sub,y_test_sub = train_test_split(x,
                                                                                    y_pos,
                                                                                    y_sub,
                                                                                    test_size = test_size,
                                                                                    shuffle=True)
    print('X train',X_train.shape)
    print('X test',X_test.shape)
    print('Y train position',y_train_pos.shape)
    print('Y train subject',y_train_sub.shape)
    print('Y test position',y_test_pos.shape)
    print('Y test subject',y_test_sub.shape)
    
    return X_train, X_test, y_train_pos, y_train_sub, y_test_pos, y_test_sub

def rot90_on_probability(image, probability= 0.5):
    if random.random() < probability:
        return tf.image.rot90(image,k=2)
    return image

def rot_on_probability(image, probability = 0.2):
    if random.random() < probability:
        return tf.keras.preprocessing.image.random_rotation(image,30, channel_axis=2)
    return image

def horiz_on_probability(image, probability = 0.2, shift = 0.1):
    if random.random() < probability:
        return tf.keras.preprocessing.image.random_shift(image,wrg=shift,hrg=0.,fill_mode='nearest', channel_axis=2)
    return image

def vertic_on_probability(image, probability = 0.2, shift = 0.1):
    if random.random() < probability:
        return tf.keras.preprocessing.image.random_shift(image,wrg=0.,hrg=shift,fill_mode='nearest', channel_axis=2)
    return image

def data_augmentation(X_train, plot=True):
    
    from tensorflow.python.ops.numpy_ops import np_config #non so perchè ma servono quest due righe
    np_config.enable_numpy_behavior() #non so perchè ma servono quest due righe
    X_train_aug = np.empty([len(X_train),64,32,1], dtype='float32')
    
    for i in tqdm(range(X_train_aug.shape[0])):
        image = X_train[i]
        image = tf.convert_to_tensor(image, np.float32)
        image = rot90_on_probability(image)
        image = rot_on_probability(image)
        image = horiz_on_probability(image)
        image = vertic_on_probability(image)
        X_train_aug[i] = image
        
    if X_train_aug.shape == X_train.shape:
        print('Data Augmentation Done!')
        
        if plot:
            plt.figure(figsize=(20,20)) 
            for i in range(10):
                seed = np.random.randint(0,1000)
                plt.subplot(5,5,i+1) 
                plt.imshow(X_train_aug[seed])
                plt.axis('off')
            plt.show()
    else:
        print('Error!')        
        
    return X_train_aug

def nn_model(n_dense=3, n_neurons=512, n_pos=3, summary=True):
    
    #input block
    input = Input(shape=(64,32,1), name='Input')
    x = tf.keras.layers.Layer()(input)

    #flatten block
    x = Flatten(name='Flatten')(x)
    
    #output block
    for i in range(n_dense):
        x = Dense(n_neurons/(2**i), activation='leaky_relu', name='Dense-{}a'.format(i+1))(x)
        
    x = Dense(50, activation='leaky_relu')(x)
    x = Dropout(0.2, name='Dropout-1')(x)    
    x1 = Dense(13, activation='softmax', name='Subject')(x)
    x2 = Dense(n_pos, activation='softmax', name='Position')(x)
    
    model = Model(inputs=input, outputs=[x1,x2], name='HDA')
    if summary:
        model.summary()
    
    pos_layer = model.layers[-1].name
    sub_layer = model.layers[-2].name
    
    return model, pos_layer, sub_layer

def cnn_model(n_conv=2, n_channels=32, n_dense=3, n_neurons=512, n_pos=3, summary=True):
    
    #input block
    input = Input(shape=(64,32,1), name='Input')
    x = tf.keras.layers.Layer()(input)
    
    #encoder block
    for i in range(n_conv):
        x = Conv2D(n_channels*(i+1), kernel_size=3, activation='leaky_relu', name='Conv-{}a'.format(i+1))(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D(name='MaxPool-{}'.format(i))(x)
        n2 = n_channels*(i+1) 
        
    for i in range(2):
        x = Conv2D(n2*(i+1), kernel_size=3, activation='leaky_relu', name='Conv-{}b'.format(i+1))(x)

    #flatten block
    x = Flatten(name='Flatten')(x)
    
    #output block
    for i in range(n_dense):
        x = Dense(n_neurons/(2**i), activation='leaky_relu', name='Dense-{}a'.format(i+1))(x)
        
    x = Dropout(0.2, name='Dropout-1')(x)    
    x1 = Dense(13, activation='softmax', name='Subject')(x)
    x2 = Dense(n_pos, activation='softmax', name='Position')(x)
    
    model = Model(inputs=input, outputs=[x1,x2], name='HDA')
    if summary:
        model.summary()
    
    pos_layer = model.layers[-1].name
    sub_layer = model.layers[-2].name
    
    return model, pos_layer, sub_layer


def cnn_rnn_model(n_conv=2, n_channels=32, n_dense=3, n_neurons=512, n_pos=3, summary=True):
    
    #input block
    input = Input(shape=(64,32,1), name='Input')
    x = tf.keras.layers.Layer()(input)
    #encoder block
    for i in range(n_conv):
        x = Conv2D(n_channels*(i+1), kernel_size=3, activation='leaky_relu', name='Conv-{}a'.format(i+1))(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D(name='MaxPool-{}'.format(i))(x)
        n2 = n_channels*(i+1) 
        
    for i in range(2):
        x = Conv2D(n2*(i+1), kernel_size=3, activation='leaky_relu', name='Conv-{}b'.format(i+1))(x)
        
    #flatten block
    x = tf.keras.layers.Reshape((x.shape[1], x.shape[3]*x.shape[2]))(x)
    x = SimpleRNN(128, return_sequences=True, activation='relu')(x)
    x = SimpleRNN(64, return_sequences=True, activation='relu')(x)
    x = SimpleRNN(32, return_sequences=False, activation='relu')(x)
    x = Flatten(name='Flatten')(x)
    
    #output block
    for i in range(n_dense):
        x = Dense(n_neurons/(2**i), activation='leaky_relu', name='Dense-{}a'.format(i+1))(x)
        
    x = Dropout(0.2, name='Dropout-1')(x)    
    x1 = Dense(13, activation='softmax', name='Subject')(x)
    x2 = Dense(n_pos, activation='softmax', name='Position')(x)
    
    model = Model(inputs=input, outputs=[x1,x2], name='HDA')
    if summary:
        model.summary()
    
    pos_layer = model.layers[-1].name
    sub_layer = model.layers[-2].name
    
    return model, pos_layer, sub_layer

def cnn_lstm_model(n_conv=2, n_channels=32, n_dense=3, n_neurons=512, n_pos=17, summary=True):
    
    #input block
    input = Input(shape=(64,32,1), name='Input')
    x = tf.keras.layers.Layer()(input)
    #encoder block
    for i in range(n_conv):
        x = Conv2D(n_channels*(i+1), kernel_size=3, activation='leaky_relu', name='Conv-{}a'.format(i+1))(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D(name='MaxPool-{}'.format(i))(x)
        n2 = n_channels*(i+1) 
        
    for i in range(1):
        x = Conv2D(n2*(i+1), kernel_size=3, activation='leaky_relu', name='Conv-{}b'.format(i+1))(x)
        
    #flatten block
    x = tf.keras.layers.Reshape((x.shape[1], x.shape[3]*x.shape[2]))(x)
    x = LSTM(40, return_sequences=True)(x)
    x = LSTM(32, return_sequences=True)(x)
    x = LSTM(32, return_sequences=False)(x)
    x = Flatten(name='Flatten')(x)
    
    #output block
    for i in range(n_dense):
        x = Dense(n_neurons/(2**i), activation='leaky_relu', name='Dense-{}a'.format(i+1))(x)
        
    x = Dropout(0.2, name='Dropout-1')(x)    
    x1 = Dense(13, activation='softmax', name='Subject')(x)
    x2 = Dense(n_pos, activation='softmax', name='Position')(x)
    
    model = Model(inputs=input, outputs=[x1,x2], name='HDA')
    if summary:
        model.summary()
    
    pos_layer = model.layers[-1].name
    sub_layer = model.layers[-2].name
    
    return model, pos_layer, sub_layer


def train_model(model, X_train, y_train_sub, y_train_pos,lambda_=0.5, verbose=1, validation_split=0.2, batch_size=100,
                n_epochs=10, plot=True, name_model='3_positions.h5'):
    
    model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy'],
              loss_weights = [lambda_,1-lambda_],
              optimizer='adam',
              metrics=['accuracy'])
    
    monitor_ = 'loss' #monitoring validation accuracy of the subjects

    my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10,monitor=monitor_),
    tf.keras.callbacks.ReduceLROnPlateau(monitor=monitor_,factor=0.5,patience=2, min_lr=0.0001)
    ]
    
    try: history = model.fit(X_train,
                    [y_train_sub,y_train_pos],
                    shuffle=True,
                    epochs=n_epochs, 
                    batch_size=batch_size,
                    validation_split = validation_split, #validate on the augmented data
                    callbacks=my_callbacks,
                    verbose=verbose)

    except KeyboardInterrupt: #stopping training saves the model
        model.save(name_model)
        print('\n ---------------------')
        print('Output saved to: {}'.format(name_model))
        print('---------------------')
        
    model.save(name_model)
    
    if plot:
        plt.plot(history.history['{}_accuracy'.format(sub_layer)])
        plt.plot(history.history['{}_accuracy'.format(pos_layer)])
        plt.plot(history.history['val_{}_accuracy'.format(sub_layer)])
        plt.plot(history.history['val_{}_accuracy'.format(pos_layer)])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend([ 'Train Subject Accuracy','Train Position Accuracy','Val Position Accuracy','Val Subject Accuracy'],
           loc='lower right')
        plt.show()
        
    return model

def test_model(X_test, y_test_sub, y_test_pos, plot=True, classification_rep=True):
    
    sub_pred, pos_pred = model.predict(X_test)
    true_sub, true_pos = y_test_sub.argmax(-1), y_test_pos.argmax(-1)
    sub_pred = sub_pred.argmax(-1)
    pos_pred = pos_pred.argmax(-1)
    
    acc_pos = round(np.sum(true_pos == pos_pred)*100/pos_pred.size,2)
    acc_sub = round(np.sum(true_sub == sub_pred)*100/sub_pred.size,2)


    print('Position Test accuracy:',acc_pos,'%')
    print('Subject Test accuracy:',acc_sub,'%')
    print('---------------------')
    print('---------------------')
    
    if classification_rep:
        print('Posture Classification report')
        print(classification_report(true_pos, pos_pred))

        print('Subject Classification report')
        print(classification_report(true_sub, sub_pred))
    
    matrix_sub = confusion_matrix(true_sub, sub_pred)
    matrix_pos = confusion_matrix(true_pos, pos_pred)
    
    if plot:
        df = pd.DataFrame(matrix_pos)
        n = matrix_pos.shape[0]
        if n==3:
            df = df.rename(columns={0:'Supine',1:'Right',2:'Left'})
        else: 
            df.columns = [1,8,9,10,11,12,15,16,17,2,4,5,13,3,6,7,14]
            df = df.rename(columns={1:'Supine',8:'Supine Star',9:'Supine Hand Crossed',10:'Supine Knees Up',
                   11:'Supine Right Knee Up',12:'Supine Left Knee Up',15:'Supine 30° Bed Inclination',16:'Supine 45° Bed Inclination',
                   17:'Supine 60° Bed Inclination',2:'Right',4:'Right 30° Body Roll',5:'Right 60° Body Roll',13:'Right Fetus',
                  3:'Left',6:'Left 30° Body Roll',7:'Left 60 Body Roll',14:'Left Fetus'})

        #normalization
        row_sums = matrix_sub.sum(axis=1)
        matrix_sub_norm = matrix_sub / row_sums[:, np.newaxis]
        row_sums = matrix_pos.sum(axis=1)
        matrix_pos_norm = matrix_pos / row_sums[:, np.newaxis]

        label_sub = [str('Subject: ')+str(i) for i in range(1,14)]

        fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,8)) 

        sns.heatmap(matrix_pos_norm, annot=matrix_pos,xticklabels=list(df.columns), yticklabels=list(df.columns),
            fmt="g",cmap='Blues',ax=ax1,vmin=0, vmax=1,square=True)
        
        if n==3:
            ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
            ax1.vlines([3],*ax1.get_xlim(), color='black',lw=2)
            ax1.hlines([3],*ax1.get_xlim(), color='black',lw=2)
            ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)
        else:
            ax1.hlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
            ax1.vlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
            ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
            ax1.vlines([17],*ax1.get_xlim(), color='black',lw=2)
            ax1.hlines([17],*ax1.get_xlim(), color='black',lw=2)
            ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)
            

        sns.heatmap(matrix_sub_norm, annot=matrix_sub,xticklabels=label_sub, yticklabels=label_sub,
            fmt="g",cmap='Blues',ax=ax2,vmin=0, vmax=1,square=True)
        ax2.hlines([0],*plt.xlim(), color='black',lw=2)
        ax2.vlines([13],*plt.xlim(), color='black',lw=2)
        ax2.hlines([13],*plt.xlim(), color='black',lw=2)
        ax2.vlines([0],*plt.xlim(), color='black',lw=2)

        plt.show()
        
    return acc_pos, acc_sub, matrix_pos, matrix_sub

# %% [markdown]
# # Preprocessing

# %%
frames = pd.read_csv('Experiment1_17pos.csv',  header=0)
frames = frames.drop(range(7939, 7951),axis=0).reset_index(drop=True)
frames = frames.drop([6767, 10147],axis=0).reset_index(drop=True)

# %%
x = frames.iloc[:,:-2].values.reshape(len(frames),64,32,1)
x = ndimage.median_filter(x, 3) 
norm = lambda s: s/1000            #1000 is the maximum value of the pressure on the sensors
x = np.array([norm(xx) for xx in x])
x_aug = data_augmentation(x, plot=False)

y_pos = frames.iloc[:,-2].values
y_pos = pd.get_dummies(frames['posture']).values

y_sub = frames.iloc[:,-1].values
y_sub = pd.get_dummies(frames['subject']).values
# Out:
# 100%|██████████| 18684/18684 [00:29<00:00, 630.10it/s]
# Data Augmentation Done!

# %% [markdown]
# # Our Model

# %%
def inception_block(input_img, n,i):
    layer_0 = Conv2D(n, (1,1), padding='same', activation='relu', name='Conv0-{}'.format(i))(input_img)
    
    layer_1 = Conv2D(n, (3,3), padding='same', activation='relu', name='Conv1-{}'.format(i))(input_img)
    layer_1 = Conv2D(n, (3,3), padding='same', activation='relu', name='Conv1a-{}'.format(i))(layer_1)

    layer_2 = Conv2D(n, (1,1), padding='same', activation='relu', name='Conv2-{}'.format(i))(input_img)
    layer_2 = Conv2D(n, (5,5), padding='same', activation='relu', name='Conv2a-{}'.format(i))(layer_2)

    layer_3 = MaxPooling2D((3,3), strides=(1,1), padding='same', name='Conv3-{}'.format(i))(input_img)
    layer_3 = Conv2D(n, (1,1), padding='same', activation='relu', name='Conv3a-{}'.format(i))(layer_3)

    mid_1 = tf.keras.layers.concatenate([layer_0,layer_1, layer_2, layer_3], axis = 3)
    return mid_1

# %%
def model_ours(n_inception=32, n_dense=32, summary=True):
    
    #input block
    input = Input(shape=(64,32,1), name='Input')

    low = inception_block(input,n_inception,'Low') 
    low_ = MaxPooling2D((2,2), strides=2, padding='same',name='MaxPool-Low')(low)
    low = Flatten(name='Flatten-Low')(low)
    low = Dense(n_dense, activation='relu', name='Dense-1-Low')(low)
    low = Dense(n_dense, activation='relu', name='Dense-2-Low')(low)
    low = Dense(n_dense, activation='relu', name='Dense-3-Low')(low)
    low = Dropout(0.1, name='Dropout-Low')(low)
    low_pos = Dense(17, activation='relu', name='Output-Low')(low)

    mid = inception_block(low_,n_inception*2,'Mid')
    mid_ = MaxPooling2D((2,2), strides=2, padding='same', name='MaxPool-Mid')(mid)
    mid = Flatten(name='Flatten-Mid')(mid)
    mid = Dense(n_dense, activation='relu', name='Dense-1-Mid')(mid)
    mid = Dense(n_dense, activation='relu', name='Dense-2-Mid')(mid)
    mid = Dense(n_dense, activation='relu', name='Dense-3-Mid')(mid)
    mid = Dropout(0.1, name='Dropout-Mid')(mid)
    mid_pos = Dense(17, activation='relu', name='Output-Mid')(mid)

    high = inception_block(mid_,n_inception*4,'High')
    high_= MaxPooling2D((2,2), strides=2, padding='same', name='MaxPool-High')(high)
    high = Flatten(name='Flatten-High')(high)
    high = Dense(n_dense, activation='relu', name='Dense-1-High')(high)
    high = Dense(n_dense, activation='relu', name='Dense-2-High')(high)
    high = Dense(n_dense, activation='relu', name='Dense-3-High')(high)
    sub = Dense(13, activation='softmax', name='Output-Subject')(high)
    high = Dropout(0.1, name='Dropout-High')(high)
    high_pos = Dense(17, activation='relu', name='Output-High')(high)
    
    pos = tf.keras.layers.Add(name='Add-Feature')([low_pos,mid_pos,high_pos])
    pos = tf.keras.layers.Activation('softmax', name='Softmax-Output')(pos)      
    
    model = Model(inputs=input, outputs=[sub, pos], name='HDA')
    if summary:
        model.summary()
    
    return model

# %%
model = model_ours(n_inception=32, n_dense=64, summary=True)

# %%
plot_model(model)

# %% [markdown]
# # K-Fold validation
#
# Every KFold has been repeated two times, just to have a more accurate results on the variance of the results.

# %% [markdown]
# ### CNN + RNN

# %%
# %%time
##### MAKE SURE ALL THE CODE ABOVE IS ALREADY RUNNED
kfold_acc_pos = []
kfold_acc_sub = []
fold=10 #number of folds
k=1

matrix_pos_ = np.zeros((17,17))
matrix_sub_ = np.zeros((13,13))

print('-----------------')
print('KFold Initialization.')
print('-----------------')

#cv = KFold(n_splits=fold, shuffle=True, random_state=123)
cv = RepeatedKFold(n_splits=fold, n_repeats=2,random_state=36851234)
for train, test in cv.split(x):

    X_train, X_test = tf.gather(x_aug, indices=train), tf.gather(x, indices=test) #ATTENZIONE 
    y_train_pos, y_test_pos = y_pos[train], y_pos[test]
    y_train_sub, y_test_sub = y_sub[train], y_sub[test]
    
    if k==1: 
        summary=True
    else: summary=False
        
    model, pos_layer, sub_layer = cnn_rnn_model(n_conv=2, n_channels=16, n_dense=3, n_neurons=256, n_pos=17, summary=summary)

    model = train_model(model, X_train, y_train_sub, y_train_pos,
                        plot=False, n_epochs=30, verbose=0, lambda_=0.5, name_model='cnn_rnn.h5')

    acc_pos, acc_sub, matrix_pos, matrix_sub = test_model(X_test,y_test_sub, y_test_pos, 
                                                          plot=False, classification_rep=False)

    matrix_sub_ += matrix_sub
    matrix_pos_ += matrix_pos

    kfold_acc_pos.append(acc_pos)
    kfold_acc_sub.append(acc_sub)

    print('{}-Kfold finished!'.format(k))
    print('-----------------')
    
    tf.keras.backend.clear_session()
    k+=1

print('-----------------')
print('-----------------')
print('Average KFold Position Accuracy:',round(np.mean(kfold_acc_pos),2),'%')
print('Standard deviation Position:',round(statistics.pstdev(kfold_acc_pos),2),'%')
print('Average Kfold Subject Accuracy:',round(np.mean(kfold_acc_sub),2),'%')
print('Standard deviation Subject:',round(statistics.pstdev(kfold_acc_sub),2),'%')
# Out:
# -----------------
# KFold Initialization.
# -----------------
# Model: "HDA"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 64, 32, 1)]  0           []
#
#  layer (Layer)                  (None, 64, 32, 1)    0           ['Input[0][0]']
#
#  Conv-1a (Conv2D)               (None, 62, 30, 16)   160         ['layer[0][0]']
#
#  batch_normalization (BatchNorm  (None, 62, 30, 16)  64          ['Conv-1a[0][0]']
#  alization)
#
#  MaxPool-0 (MaxPooling2D)       (None, 31, 15, 16)   0           ['batch_normalization[0][0]']
#
#  Conv-2a (Conv2D)               (None, 29, 13, 32)   4640        ['MaxPool-0[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 29, 13, 32)  128         ['Conv-2a[0][0]']
#  rmalization)
#
#  MaxPool-1 (MaxPooling2D)       (None, 14, 6, 32)    0           ['batch_normalization_1[0][0]']
#
#  Conv-1b (Conv2D)               (None, 12, 4, 32)    9248        ['MaxPool-1[0][0]']
#
#  Conv-2b (Conv2D)               (None, 10, 2, 64)    18496       ['Conv-1b[0][0]']
#
#  reshape (Reshape)              (None, 10, 128)      0           ['Conv-2b[0][0]']
#
#  simple_rnn (SimpleRNN)         (None, 10, 128)      32896       ['reshape[0][0]']
#
#  simple_rnn_1 (SimpleRNN)       (None, 10, 64)       12352       ['simple_rnn[0][0]']
#
#  simple_rnn_2 (SimpleRNN)       (None, 32)           3104        ['simple_rnn_1[0][0]']
#
#  Flatten (Flatten)              (None, 32)           0           ['simple_rnn_2[0][0]']
#
#  Dense-1a (Dense)               (None, 256)          8448        ['Flatten[0][0]']
#
#  Dense-2a (Dense)               (None, 128)          32896       ['Dense-1a[0][0]']
#
#  Dense-3a (Dense)               (None, 64)           8256        ['Dense-2a[0][0]']
#
#  Dropout-1 (Dropout)            (None, 64)           0           ['Dense-3a[0][0]']
#
#  Subject (Dense)                (None, 13)           845         ['Dropout-1[0][0]']
#
#  Position (Dense)               (None, 17)           1105        ['Dropout-1[0][0]']
#
# ==================================================================================================
# Total params: 132,638
# Trainable params: 132,542
# Non-trainable params: 96
# __________________________________________________________________________________________________
# Position Test accuracy: 99.52 %
# Subject Test accuracy: 99.2 %
# ---------------------
# ---------------------
# 1-Kfold finished!
# -----------------
# Position Test accuracy: 96.31 %
# Subject Test accuracy: 94.7 %
# ---------------------
# ---------------------
# 2-Kfold finished!
# -----------------
# Position Test accuracy: 97.0 %
# Subject Test accuracy: 92.94 %
# ---------------------
# ---------------------
# 3-Kfold finished!
# -----------------
# Position Test accuracy: 98.82 %
# Subject Test accuracy: 99.84 %
# ---------------------
# ---------------------
# 4-Kfold finished!
# -----------------
# Position Test accuracy: 99.89 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 5-Kfold finished!
# -----------------
# Position Test accuracy: 99.73 %
# Subject Test accuracy: 99.95 %
# ---------------------
# ---------------------
# 6-Kfold finished!
# -----------------
# Position Test accuracy: 99.36 %
# Subject Test accuracy: 99.41 %
# ---------------------
# ---------------------
# 7-Kfold finished!
# -----------------
# Position Test accuracy: 100.0 %
# Subject Test accuracy: 100.0 %
# ---------------------
# ---------------------
# 8-Kfold finished!
# -----------------
# Position Test accuracy: 99.84 %
# Subject Test accuracy: 99.2 %
# ---------------------
# ---------------------
# 9-Kfold finished!
# -----------------
# Position Test accuracy: 99.73 %
# Subject Test accuracy: 99.68 %
# ---------------------
# ---------------------
# 10-Kfold finished!
# -----------------
# Position Test accuracy: 98.93 %
# Subject Test accuracy: 95.88 %
# ---------------------
# ---------------------
# 11-Kfold finished!
# -----------------
# Position Test accuracy: 99.73 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 12-Kfold finished!
# -----------------
# Position Test accuracy: 99.95 %
# Subject Test accuracy: 99.95 %
# ---------------------
# ---------------------
# 13-Kfold finished!
# -----------------
# Position Test accuracy: 99.3 %
# Subject Test accuracy: 99.25 %
# ---------------------
# ---------------------
# 14-Kfold finished!
# -----------------
# Position Test accuracy: 99.84 %
# Subject Test accuracy: 99.84 %
# ---------------------
# ---------------------
# 15-Kfold finished!
# -----------------
# Position Test accuracy: 99.52 %
# Subject Test accuracy: 99.73 %
# ---------------------
# ---------------------
# 16-Kfold finished!
# -----------------
# Position Test accuracy: 99.14 %
# Subject Test accuracy: 99.2 %
# ---------------------
# ---------------------
# 17-Kfold finished!
# -----------------
# Position Test accuracy: 99.84 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 18-Kfold finished!
# -----------------
# Position Test accuracy: 90.15 %
# Subject Test accuracy: 97.32 %
# ---------------------
# ---------------------
# 19-Kfold finished!
# -----------------
# Position Test accuracy: 99.14 %
# Subject Test accuracy: 96.31 %
# ---------------------
# ---------------------
# 20-Kfold finished!
# -----------------
# -----------------
# -----------------
# Average KFold Position Accuracy: 98.79 %
# Standard deviation Position: 2.19 %
# Average Kfold Subject Accuracy: 98.6 %
# Standard deviation Subject: 2.0 %
# CPU times: user 10h 12min 32s, sys: 38min 31s, total: 10h 51min 3s
# Wall time: 5h 54min 26s

# %%
df = pd.DataFrame(matrix_pos_)
df.columns = [1,8,9,10,11,12,15,16,17,2,4,5,13,3,6,7,14]
df = df.rename(columns={1:'Supine',8:'Supine Star',9:'Supine Hand Crossed',10:'Supine Knees Up',
                   11:'Supine Right Knee Up',12:'Supine Left Knee Up',15:'Supine 30° Bed Inclination',16:'Supine 45° Bed Inclination',
                   17:'Supine 60° Bed Inclination',2:'Right',4:'Right 30° Body Roll',5:'Right 60° Body Roll',13:'Right Fetus',
                  3:'Left',6:'Left 30° Body Roll',7:'Left 60 Body Roll',14:'Left Fetus'})

#normalization
row_sums = matrix_sub_.sum(axis=1)
matrix_sub_norm = matrix_sub_ / row_sums[:, np.newaxis]
row_sums = matrix_pos_.sum(axis=1)
matrix_pos_norm = matrix_pos_ / row_sums[:, np.newaxis]

label_sub = [str('Subject: ')+str(i) for i in range(1,14)]

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,8)) 

sns.heatmap(matrix_pos_norm, annot=matrix_pos_,xticklabels=list(df.columns), yticklabels=list(df.columns),
            fmt="g",cmap='Blues',ax=ax1,vmin=0, vmax=1,square=True)
ax1.hlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)

sns.heatmap(matrix_sub_norm, annot=matrix_sub_,xticklabels=label_sub, yticklabels=label_sub,
            fmt="g",cmap='Blues',ax=ax2,vmin=0, vmax=1,square=True)
ax2.hlines([0],*plt.xlim(), color='black',lw=2)
ax2.vlines([13],*plt.xlim(), color='black',lw=2)
ax2.hlines([13],*plt.xlim(), color='black',lw=2)
ax2.vlines([0],*plt.xlim(), color='black',lw=2)

plt.show()

# %% [markdown]
# ### CNN + LSTM

# %%
# %%time
##### MAKE SURE ALL THE CODE ABOVE IS ALREADY RUNNED
kfold_acc_pos = []
kfold_acc_sub = []
fold=10 #number of folds
k=1

matrix_pos_ = np.zeros((17,17))
matrix_sub_ = np.zeros((13,13))

print('-----------------')
print('KFold Initialization.')
print('-----------------')
#cv = KFold(n_splits=fold, shuffle=True, random_state=123)
cv = RepeatedKFold(n_splits=fold, n_repeats=2,random_state=36851234)
for train, test in cv.split(x):

    X_train, X_test = tf.gather(x_aug, indices=train), tf.gather(x, indices=test) #ATTENZIONE 
    y_train_pos, y_test_pos = y_pos[train], y_pos[test]
    y_train_sub, y_test_sub = y_sub[train], y_sub[test]
    
    if k==1: 
        summary=True
    else: summary=False
        
    model, pos_layer, sub_layer = cnn_lstm_model(n_conv=2, n_channels=32, n_dense=2, n_neurons=64, n_pos=17, summary=summary)

    model = train_model(model, X_train, y_train_sub, y_train_pos,
                        plot=False, n_epochs=30, verbose=0, lambda_=0.5, name_model='cnn_lstm.h5')

    acc_pos, acc_sub, matrix_pos, matrix_sub = test_model(X_test,y_test_sub, y_test_pos, 
                                                          plot=False, classification_rep=False)

    matrix_sub_ += matrix_sub
    matrix_pos_ += matrix_pos

    kfold_acc_pos.append(acc_pos)
    kfold_acc_sub.append(acc_sub)
    
    print('{}-Kfold finished!'.format(k))
    print('-----------------')
    
    tf.keras.backend.clear_session()
    k+=1

print('-----------------')
print('-----------------')
print('Average KFold Position Accuracy:',round(np.mean(kfold_acc_pos),2),'%')
print('Standard deviation Position:',round(statistics.pstdev(kfold_acc_pos),2),'%')
print('Average Kfold Subject Accuracy:',round(np.mean(kfold_acc_sub),2),'%')
print('Standard deviation Subject:',round(statistics.pstdev(kfold_acc_sub),2),'%')
# Out:
# -----------------
# KFold Initialization.
# -----------------
# Model: "HDA"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 64, 32, 1)]  0           []
#
#  layer (Layer)                  (None, 64, 32, 1)    0           ['Input[0][0]']
#
#  Conv-1a (Conv2D)               (None, 62, 30, 32)   320         ['layer[0][0]']
#
#  batch_normalization (BatchNorm  (None, 62, 30, 32)  128         ['Conv-1a[0][0]']
#  alization)
#
#  MaxPool-0 (MaxPooling2D)       (None, 31, 15, 32)   0           ['batch_normalization[0][0]']
#
#  Conv-2a (Conv2D)               (None, 29, 13, 64)   18496       ['MaxPool-0[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 29, 13, 64)  256         ['Conv-2a[0][0]']
#  rmalization)
#
#  MaxPool-1 (MaxPooling2D)       (None, 14, 6, 64)    0           ['batch_normalization_1[0][0]']
#
#  Conv-1b (Conv2D)               (None, 12, 4, 64)    36928       ['MaxPool-1[0][0]']
#
#  reshape (Reshape)              (None, 12, 256)      0           ['Conv-1b[0][0]']
#
#  lstm (LSTM)                    (None, 12, 40)       47520       ['reshape[0][0]']
#
#  lstm_1 (LSTM)                  (None, 12, 32)       9344        ['lstm[0][0]']
#
#  lstm_2 (LSTM)                  (None, 32)           8320        ['lstm_1[0][0]']
#
#  Flatten (Flatten)              (None, 32)           0           ['lstm_2[0][0]']
#
#  Dense-1a (Dense)               (None, 64)           2112        ['Flatten[0][0]']
#
#  Dense-2a (Dense)               (None, 32)           2080        ['Dense-1a[0][0]']
#
#  Dropout-1 (Dropout)            (None, 32)           0           ['Dense-2a[0][0]']
#
#  Subject (Dense)                (None, 13)           429         ['Dropout-1[0][0]']
#
#  Position (Dense)               (None, 17)           561         ['Dropout-1[0][0]']
#
# ==================================================================================================
# Total params: 126,494
# Trainable params: 126,302
# Non-trainable params: 192
# __________________________________________________________________________________________________
# Position Test accuracy: 99.73 %
# Subject Test accuracy: 97.97 %
# ---------------------
# ---------------------
# 1-Kfold finished!
# -----------------
# Position Test accuracy: 98.82 %
# Subject Test accuracy: 90.26 %
# ---------------------
# ---------------------
# 2-Kfold finished!
# -----------------
# Position Test accuracy: 99.04 %
# Subject Test accuracy: 99.3 %
# ---------------------
# ---------------------
# 3-Kfold finished!
# -----------------
# Position Test accuracy: 65.33 %
# Subject Test accuracy: 72.77 %
# ---------------------
# ---------------------
# 4-Kfold finished!
# -----------------
# Position Test accuracy: 97.43 %
# Subject Test accuracy: 98.29 %
# ---------------------
# ---------------------
# 5-Kfold finished!
# -----------------
# Position Test accuracy: 97.64 %
# Subject Test accuracy: 81.64 %
# ---------------------
# ---------------------
# 6-Kfold finished!
# -----------------
# Position Test accuracy: 99.52 %
# Subject Test accuracy: 98.66 %
# ---------------------
# ---------------------
# 7-Kfold finished!
# -----------------
# Position Test accuracy: 99.79 %
# Subject Test accuracy: 99.73 %
# ---------------------
# ---------------------
# 8-Kfold finished!
# -----------------
# Position Test accuracy: 99.46 %
# Subject Test accuracy: 97.06 %
# ---------------------
# ---------------------
# 9-Kfold finished!
# -----------------
# Position Test accuracy: 80.94 %
# Subject Test accuracy: 62.74 %
# ---------------------
# ---------------------
# 10-Kfold finished!
# -----------------
# Position Test accuracy: 99.79 %
# Subject Test accuracy: 98.39 %
# ---------------------
# ---------------------
# 11-Kfold finished!
# -----------------
# Position Test accuracy: 97.49 %
# Subject Test accuracy: 93.2 %
# ---------------------
# ---------------------
# 12-Kfold finished!
# -----------------
# Position Test accuracy: 99.89 %
# Subject Test accuracy: 99.63 %
# ---------------------
# ---------------------
# 13-Kfold finished!
# -----------------
# Position Test accuracy: 92.72 %
# Subject Test accuracy: 91.49 %
# ---------------------
# ---------------------
# 14-Kfold finished!
# -----------------
# Position Test accuracy: 98.5 %
# Subject Test accuracy: 99.46 %
# ---------------------
# ---------------------
# 15-Kfold finished!
# -----------------
# Position Test accuracy: 98.07 %
# Subject Test accuracy: 90.95 %
# ---------------------
# ---------------------
# 16-Kfold finished!
# -----------------
# Position Test accuracy: 99.68 %
# Subject Test accuracy: 99.73 %
# ---------------------
# ---------------------
# 17-Kfold finished!
# -----------------
# Position Test accuracy: 84.85 %
# Subject Test accuracy: 86.99 %
# ---------------------
# ---------------------
# 18-Kfold finished!
# -----------------
# Position Test accuracy: 99.79 %
# Subject Test accuracy: 99.79 %
# ---------------------
# ---------------------
# 19-Kfold finished!
# -----------------
# Position Test accuracy: 91.01 %
# Subject Test accuracy: 93.15 %
# ---------------------
# ---------------------
# 20-Kfold finished!
# -----------------
# -----------------
# -----------------
# Average KFold Position Accuracy: 94.97 %
# Standard deviation Position: 8.52 %
# Average Kfold Subject Accuracy: 92.56 %
# Standard deviation Subject: 9.73 %
# CPU times: user 45min 54s, sys: 2min 37s, total: 48min 32s
# Wall time: 50min 47s

# %%
df = pd.DataFrame(matrix_pos_)
df.columns = [1,8,9,10,11,12,15,16,17,2,4,5,13,3,6,7,14]
df = df.rename(columns={1:'Supine',8:'Supine Star',9:'Supine Hand Crossed',10:'Supine Knees Up',
                   11:'Supine Right Knee Up',12:'Supine Left Knee Up',15:'Supine 30° Bed Inclination',16:'Supine 45° Bed Inclination',
                   17:'Supine 60° Bed Inclination',2:'Right',4:'Right 30° Body Roll',5:'Right 60° Body Roll',13:'Right Fetus',
                  3:'Left',6:'Left 30° Body Roll',7:'Left 60 Body Roll',14:'Left Fetus'})

#normalization
row_sums = matrix_sub_.sum(axis=1)
matrix_sub_norm = matrix_sub_ / row_sums[:, np.newaxis]
row_sums = matrix_pos_.sum(axis=1)
matrix_pos_norm = matrix_pos_ / row_sums[:, np.newaxis]

label_sub = [str('Subject: ')+str(i) for i in range(1,14)]

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,8)) 

sns.heatmap(matrix_pos_norm, annot=matrix_pos_,xticklabels=list(df.columns), yticklabels=list(df.columns),
            fmt="g",cmap='Blues',ax=ax1,vmin=0, vmax=1,square=True)
ax1.hlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)

sns.heatmap(matrix_sub_norm, annot=matrix_sub_,xticklabels=label_sub, yticklabels=label_sub,
            fmt="g",cmap='Blues',ax=ax2,vmin=0, vmax=1,square=True)
ax2.hlines([0],*plt.xlim(), color='black',lw=2)
ax2.vlines([13],*plt.xlim(), color='black',lw=2)
ax2.hlines([13],*plt.xlim(), color='black',lw=2)
ax2.vlines([0],*plt.xlim(), color='black',lw=2)

plt.show()

# %% [markdown]
# ### CNN

# %%
# %%time
##### MAKE SURE ALL THE CODE ABOVE IS ALREADY RUNNED
kfold_acc_pos = []
kfold_acc_sub = []
fold=10 #number of folds
k=1

matrix_pos_ = np.zeros((17,17))
matrix_sub_ = np.zeros((13,13))

print('-----------------')
print('KFold Initialization.')
print('-----------------')

#cv = KFold(n_splits=fold, shuffle=True, random_state=123)
cv = RepeatedKFold(n_splits=fold, n_repeats=2,random_state=36851234)
for train, test in cv.split(x):

    X_train, X_test = tf.gather(x_aug, indices=train), tf.gather(x, indices=test) #ATTENZIONE 
    y_train_pos, y_test_pos = y_pos[train], y_pos[test]
    y_train_sub, y_test_sub = y_sub[train], y_sub[test]
    
    if k==1: 
        summary=True
    else: summary=False
        
    model, pos_layer, sub_layer = cnn_model(n_conv=2, n_channels=16, n_dense=2, n_neurons=64, n_pos=17, summary=summary)

    model = train_model(model, X_train, y_train_sub, y_train_pos,
                        plot=False, n_epochs=30, verbose=0, lambda_=0.5, name_model='cnn.h5')

    acc_pos, acc_sub, matrix_pos, matrix_sub = test_model(X_test,y_test_sub, y_test_pos, 
                                                          plot=False, classification_rep=False)

    matrix_sub_ += matrix_sub
    matrix_pos_ += matrix_pos

    kfold_acc_pos.append(acc_pos)
    kfold_acc_sub.append(acc_sub)

    print('{}-Kfold finished!'.format(k))
    print('-----------------')
    
    tf.keras.backend.clear_session()
    k+=1

print('-----------------')
print('-----------------')
print('Average KFold Position Accuracy:',round(np.mean(kfold_acc_pos),2),'%')
print('Standard deviation Position:',round(statistics.pstdev(kfold_acc_pos),2),'%')
print('Average Kfold Subject Accuracy:',round(np.mean(kfold_acc_sub),2),'%')
print('Standard deviation Subject:',round(statistics.pstdev(kfold_acc_sub),2),'%')
# Out:
# -----------------
# KFold Initialization.
# -----------------
# Model: "HDA"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 64, 32, 1)]  0           []
#
#  layer (Layer)                  (None, 64, 32, 1)    0           ['Input[0][0]']
#
#  Conv-1a (Conv2D)               (None, 62, 30, 16)   160         ['layer[0][0]']
#
#  batch_normalization (BatchNorm  (None, 62, 30, 16)  64          ['Conv-1a[0][0]']
#  alization)
#
#  MaxPool-0 (MaxPooling2D)       (None, 31, 15, 16)   0           ['batch_normalization[0][0]']
#
#  Conv-2a (Conv2D)               (None, 29, 13, 32)   4640        ['MaxPool-0[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 29, 13, 32)  128         ['Conv-2a[0][0]']
#  rmalization)
#
#  MaxPool-1 (MaxPooling2D)       (None, 14, 6, 32)    0           ['batch_normalization_1[0][0]']
#
#  Conv-1b (Conv2D)               (None, 12, 4, 32)    9248        ['MaxPool-1[0][0]']
#
#  Conv-2b (Conv2D)               (None, 10, 2, 64)    18496       ['Conv-1b[0][0]']
#
#  Flatten (Flatten)              (None, 1280)         0           ['Conv-2b[0][0]']
#
#  Dense-1a (Dense)               (None, 64)           81984       ['Flatten[0][0]']
#
#  Dense-2a (Dense)               (None, 32)           2080        ['Dense-1a[0][0]']
#
#  Dropout-1 (Dropout)            (None, 32)           0           ['Dense-2a[0][0]']
#
#  Subject (Dense)                (None, 13)           429         ['Dropout-1[0][0]']
#
#  Position (Dense)               (None, 17)           561         ['Dropout-1[0][0]']
#
# ==================================================================================================
# Total params: 117,790
# Trainable params: 117,694
# Non-trainable params: 96
# __________________________________________________________________________________________________
# Position Test accuracy: 99.41 %
# Subject Test accuracy: 99.73 %
# ---------------------
# ---------------------
# 1-Kfold finished!
# -----------------
# Position Test accuracy: 99.73 %
# Subject Test accuracy: 99.84 %
# ---------------------
# ---------------------
# 2-Kfold finished!
# -----------------
# Position Test accuracy: 99.79 %
# Subject Test accuracy: 99.84 %
# ---------------------
# ---------------------
# 3-Kfold finished!
# -----------------
# Position Test accuracy: 99.84 %
# Subject Test accuracy: 99.79 %
# ---------------------
# ---------------------
# 4-Kfold finished!
# -----------------
# Position Test accuracy: 99.79 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 5-Kfold finished!
# -----------------
# Position Test accuracy: 99.68 %
# Subject Test accuracy: 99.95 %
# ---------------------
# ---------------------
# 6-Kfold finished!
# -----------------
# Position Test accuracy: 99.84 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 7-Kfold finished!
# -----------------
# Position Test accuracy: 99.89 %
# Subject Test accuracy: 99.84 %
# ---------------------
# ---------------------
# 8-Kfold finished!
# -----------------
# Position Test accuracy: 100.0 %
# Subject Test accuracy: 99.68 %
# ---------------------
# ---------------------
# 9-Kfold finished!
# -----------------
# Position Test accuracy: 98.72 %
# Subject Test accuracy: 99.3 %
# ---------------------
# ---------------------
# 10-Kfold finished!
# -----------------
# Position Test accuracy: 99.84 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 11-Kfold finished!
# -----------------
# Position Test accuracy: 98.66 %
# Subject Test accuracy: 90.16 %
# ---------------------
# ---------------------
# 12-Kfold finished!
# -----------------
# Position Test accuracy: 99.79 %
# Subject Test accuracy: 99.63 %
# ---------------------
# ---------------------
# 13-Kfold finished!
# -----------------
# Position Test accuracy: 99.95 %
# Subject Test accuracy: 99.95 %
# ---------------------
# ---------------------
# 14-Kfold finished!
# -----------------
# Position Test accuracy: 99.89 %
# Subject Test accuracy: 100.0 %
# ---------------------
# ---------------------
# 15-Kfold finished!
# -----------------
# Position Test accuracy: 99.73 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 16-Kfold finished!
# -----------------
# Position Test accuracy: 99.95 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 17-Kfold finished!
# -----------------
# Position Test accuracy: 99.89 %
# Subject Test accuracy: 99.84 %
# ---------------------
# ---------------------
# 18-Kfold finished!
# -----------------
# Position Test accuracy: 99.25 %
# Subject Test accuracy: 99.89 %
# ---------------------
# ---------------------
# 19-Kfold finished!
# -----------------
# Position Test accuracy: 99.68 %
# Subject Test accuracy: 99.63 %
# ---------------------
# ---------------------
# 20-Kfold finished!
# -----------------
# -----------------
# -----------------
# Average KFold Position Accuracy: 99.67 %
# Standard deviation Position: 0.37 %
# Average Kfold Subject Accuracy: 99.33 %
# Standard deviation Subject: 2.11 %
# CPU times: user 18min 50s, sys: 1min 26s, total: 20min 16s
# Wall time: 23min 35s

# %% [markdown]
# # LOSO Validation Scheme
#
#   - LOSO = Leave on Subject out, basically we trained on the other 12 subjects and tested on the last one. This has been reiterated for all the subjects.

# %%
groups = frames["subject"]
logo = LeaveOneGroupOut()

# %% [markdown]
# ### CNN

# %%
kfold_acc_pos = []
kfold_acc_sub = []
fold=10 #number of folds
k=1

matrix_pos_ = np.zeros((17,17))
matrix_sub_ = np.zeros((13,13))

k=0
for train_index, test_index in logo.split(x, y_pos, groups):
  
  model, pos_layer, sub_layer = cnn_model(n_conv=2, n_channels=16, n_dense=2, n_neurons=64, n_pos=17,summary=False)
    
  model = train_model(model, x_aug[train_index], y_sub[train_index], y_pos[train_index], plot=False,
                      n_epochs=50, lambda_=0.5, verbose=0,batch_size=100)
    
  acc_pos, acc_sub, matrix_pos, matrix_sub = test_model(x[test_index], y_sub[test_index], y_pos[test_index], 
                                                          plot=False, classification_rep=False)
  
  matrix_sub_ += 0
  matrix_pos_ += matrix_pos

  kfold_acc_pos.append(acc_pos)
  kfold_acc_sub.append(acc_sub)
  
  print('{}- finished!'.format(k))
  print('-----------------')
    
  tf.keras.backend.clear_session()
  k+=1

print('-----------------')
print('-----------------')
print('Average KFold Position Accuracy:',round(np.mean(kfold_acc_pos),2),'%')
print('Standard deviation Position:',round(statistics.pstdev(kfold_acc_pos),2),'%')

# %%
df = pd.DataFrame(matrix_pos_)
df.columns = [1,8,9,10,11,12,15,16,17,2,4,5,13,3,6,7,14]
df = df.rename(columns={1:'Supine',8:'Supine Star',9:'Supine Hand Crossed',10:'Supine Knees Up',
                   11:'Supine Right Knee Up',12:'Supine Left Knee Up',15:'Supine 30° Bed Inclination',16:'Supine 45° Bed Inclination',
                   17:'Supine 60° Bed Inclination',2:'Right',4:'Right 30° Body Roll',5:'Right 60° Body Roll',13:'Right Fetus',
                  3:'Left',6:'Left 30° Body Roll',7:'Left 60 Body Roll',14:'Left Fetus'})

#normalization
row_sums = matrix_sub_.sum(axis=1)
matrix_sub_norm = matrix_sub_ / row_sums[:, np.newaxis]
row_sums = matrix_pos_.sum(axis=1)
matrix_pos_norm = matrix_pos_ / row_sums[:, np.newaxis]

label_sub = [str('Subject: ')+str(i) for i in range(1,14)]

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,8)) 

sns.heatmap(matrix_pos_norm, annot=matrix_pos_,xticklabels=list(df.columns), yticklabels=list(df.columns),
            fmt="g",cmap='Blues',ax=ax1,vmin=0, vmax=1,square=True)
ax1.hlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)

sns.heatmap(matrix_sub_norm, annot=matrix_sub_,xticklabels=label_sub, yticklabels=label_sub,
            fmt="g",cmap='Blues',ax=ax2,vmin=0, vmax=1,square=True)
ax2.hlines([0],*plt.xlim(), color='black',lw=2)
ax2.vlines([13],*plt.xlim(), color='black',lw=2)
ax2.hlines([13],*plt.xlim(), color='black',lw=2)
ax2.vlines([0],*plt.xlim(), color='black',lw=2)

plt.show()

# %% [markdown]
# ### CNN+RNN

# %%
kfold_acc_pos = []
kfold_acc_sub = []
fold=10 #number of folds
k=1

matrix_pos_ = np.zeros((17,17))
matrix_sub_ = np.zeros((13,13))

k=0
for train_index, test_index in logo.split(x, y_pos, groups):
  
  model, pos_layer, sub_layer = cnn_rnn_model(n_conv=2, n_channels=16, n_dense=3, n_neurons=256, n_pos=17, summary=False)
    
  model = train_model(model, x_aug[train_index], y_sub[train_index], y_pos[train_index], plot=False,
                      n_epochs=50, lambda_=0.5, verbose=0, batch_size=100)
    
  acc_pos, acc_sub, matrix_pos, matrix_sub = test_model(x[test_index], y_sub[test_index], y_pos[test_index], 
                                                          plot=False, classification_rep=False)
  
  matrix_sub_ += 0
  matrix_pos_ += matrix_pos

  kfold_acc_pos.append(acc_pos)
  kfold_acc_sub.append(acc_sub)
  
  print('{}- finished!'.format(k))
  print('-----------------')
    
  tf.keras.backend.clear_session()
  k+=1

print('-----------------')
print('-----------------')
print('Average KFold Position Accuracy:',round(np.mean(kfold_acc_pos),2),'%')
print('Standard deviation Position:',round(statistics.pstdev(kfold_acc_pos),2),'%')

# %%
df = pd.DataFrame(matrix_pos_)
df.columns = [1,8,9,10,11,12,15,16,17,2,4,5,13,3,6,7,14]
df = df.rename(columns={1:'Supine',8:'Supine Star',9:'Supine Hand Crossed',10:'Supine Knees Up',
                   11:'Supine Right Knee Up',12:'Supine Left Knee Up',15:'Supine 30° Bed Inclination',16:'Supine 45° Bed Inclination',
                   17:'Supine 60° Bed Inclination',2:'Right',4:'Right 30° Body Roll',5:'Right 60° Body Roll',13:'Right Fetus',
                  3:'Left',6:'Left 30° Body Roll',7:'Left 60 Body Roll',14:'Left Fetus'})

#normalization
row_sums = matrix_sub_.sum(axis=1)
matrix_sub_norm = matrix_sub_ / row_sums[:, np.newaxis]
row_sums = matrix_pos_.sum(axis=1)
matrix_pos_norm = matrix_pos_ / row_sums[:, np.newaxis]

label_sub = [str('Subject: ')+str(i) for i in range(1,14)]

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,8)) 

sns.heatmap(matrix_pos_norm, annot=matrix_pos_,xticklabels=list(df.columns), yticklabels=list(df.columns),
            fmt="g",cmap='Blues',ax=ax1,vmin=0, vmax=1,square=True)
ax1.hlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)

sns.heatmap(matrix_sub_norm, annot=matrix_sub_,xticklabels=label_sub, yticklabels=label_sub,
            fmt="g",cmap='Blues',ax=ax2,vmin=0, vmax=1,square=True)
ax2.hlines([0],*plt.xlim(), color='black',lw=2)
ax2.vlines([13],*plt.xlim(), color='black',lw=2)
ax2.hlines([13],*plt.xlim(), color='black',lw=2)
ax2.vlines([0],*plt.xlim(), color='black',lw=2)

plt.show()

# %% [markdown]
# ### CNN+LSTM

# %%
kfold_acc_pos = []
kfold_acc_sub = []
fold=10 #number of folds
k=1

matrix_pos_ = np.zeros((17,17))
matrix_sub_ = np.zeros((13,13))

k=0
for train_index, test_index in logo.split(x, y_pos, groups):
  
  model, pos_layer, sub_layer = cnn_lstm_model(n_conv=2, n_channels=32, n_dense=2, n_neurons=64, n_pos=17, summary=False)
    
  model = train_model(model, x_aug[train_index], y_sub[train_index], y_pos[train_index], plot=False,
                      n_epochs=50, lambda_=0.5, verbose=0, batch_size=100)
    
  acc_pos, acc_sub, matrix_pos, matrix_sub = test_model(x[test_index], y_sub[test_index], y_pos[test_index], 
                                                          plot=False, classification_rep=False)
  
  matrix_sub_ += 0
  matrix_pos_ += matrix_pos

  kfold_acc_pos.append(acc_pos)
  kfold_acc_sub.append(acc_sub)
  
  print('{}- finished!'.format(k))
  print('-----------------')
    
  tf.keras.backend.clear_session()
  k+=1

print('-----------------')
print('-----------------')
print('Average KFold Position Accuracy:',round(np.mean(kfold_acc_pos),2),'%')
print('Standard deviation Position:',round(statistics.pstdev(kfold_acc_pos),2),'%')

# %%
df = pd.DataFrame(matrix_pos_)
df.columns = [1,8,9,10,11,12,15,16,17,2,4,5,13,3,6,7,14]
df = df.rename(columns={1:'Supine',8:'Supine Star',9:'Supine Hand Crossed',10:'Supine Knees Up',
                   11:'Supine Right Knee Up',12:'Supine Left Knee Up',15:'Supine 30° Bed Inclination',16:'Supine 45° Bed Inclination',
                   17:'Supine 60° Bed Inclination',2:'Right',4:'Right 30° Body Roll',5:'Right 60° Body Roll',13:'Right Fetus',
                  3:'Left',6:'Left 30° Body Roll',7:'Left 60 Body Roll',14:'Left Fetus'})

#normalization
row_sums = matrix_sub_.sum(axis=1)
matrix_sub_norm = matrix_sub_ / row_sums[:, np.newaxis]
row_sums = matrix_pos_.sum(axis=1)
matrix_pos_norm = matrix_pos_ / row_sums[:, np.newaxis]

label_sub = [str('Subject: ')+str(i) for i in range(1,14)]

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,8)) 

sns.heatmap(matrix_pos_norm, annot=matrix_pos_,xticklabels=list(df.columns), yticklabels=list(df.columns),
            fmt="g",cmap='Blues',ax=ax1,vmin=0, vmax=1,square=True)
ax1.hlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)

sns.heatmap(matrix_sub_norm, annot=matrix_sub_,xticklabels=label_sub, yticklabels=label_sub,
            fmt="g",cmap='Blues',ax=ax2,vmin=0, vmax=1,square=True)
ax2.hlines([0],*plt.xlim(), color='black',lw=2)
ax2.vlines([13],*plt.xlim(), color='black',lw=2)
ax2.hlines([13],*plt.xlim(), color='black',lw=2)
ax2.vlines([0],*plt.xlim(), color='black',lw=2)

plt.show()

# %% [markdown]
# ### Our Model LOSO Validation
#
# The same cell has been used for the KFold validation with some few modifications.
# Of course for the LOSO validation the subject confusion matrix is useless

# %%
kfold_acc_pos = []
kfold_acc_sub = []
k=1

groups = frames["subject"]
logo = LeaveOneGroupOut()

matrix_pos_ = np.zeros((17,17))
matrix_sub_ = np.zeros((13,13))

k=1
for train_index, test_index in logo.split(x, y_pos, groups):
  
  model = model2(n_inception=32, n_dense=64, summary=False)    

  model = train_model(model, x_aug[train_index], y_sub[train_index], y_pos[train_index], plot=False,
                      n_epochs=10, lambda_=0.2, verbose=1, batch_size=100)
    
  acc_pos, acc_sub, matrix_pos, matrix_sub = test_model(x[test_index], y_sub[test_index], y_pos[test_index], 
                                                          plot=False, classification_rep=False)
  
  matrix_sub_ += 0
  matrix_pos_ += matrix_pos

  kfold_acc_pos.append(acc_pos)
  kfold_acc_sub.append(acc_sub)
  
  print('{}- finished!'.format(k))
  print('-----------------')
    
  tf.keras.backend.clear_session()
  k+=1

print('-----------------')
print('Average KFold Position Accuracy:',round(np.mean(kfold_acc_pos),2),'%')
print('Standard deviation Position:',round(statistics.pstdev(kfold_acc_pos),2),'%')
# Out:
# Epoch 1/10
# 175/175 [==============================] - 47s 169ms/step - loss: 1.1063 - Output-Subject_loss: 2.2676 - Softmax-Output_loss: 0.8160 - Output-Subject_accuracy: 0.2336 - Softmax-Output_accuracy: 0.7609 - lr: 0.0010
# Epoch 2/10
# 175/175 [==============================] - 27s 155ms/step - loss: 0.3796 - Output-Subject_loss: 1.1679 - Softmax-Output_loss: 0.1825 - Output-Subject_accuracy: 0.6252 - Softmax-Output_accuracy: 0.9441 - lr: 0.0010
# Epoch 3/10
# 175/175 [==============================] - 28s 159ms/step - loss: 0.1986 - Output-Subject_loss: 0.5826 - Softmax-Output_loss: 0.1026 - Output-Subject_accuracy: 0.8337 - Softmax-Output_accuracy: 0.9684 - lr: 0.0010
# Epoch 4/10
# 175/175 [==============================] - 28s 163ms/step - loss: 0.1165 - Output-Subject_loss: 0.3307 - Softmax-Output_loss: 0.0629 - Output-Subject_accuracy: 0.9076 - Softmax-Output_accuracy: 0.9814 - lr: 0.0010
# Epoch 5/10
# 175/175 [==============================] - 28s 161ms/step - loss: 0.0901 - Output-Subject_loss: 0.2311 - Softmax-Output_loss: 0.0548 - Output-Subject_accuracy: 0.9340 - Softmax-Output_accuracy: 0.9839 - lr: 0.0010
# Epoch 6/10
# 175/175 [==============================] - 28s 161ms/step - loss: 0.0696 - Output-Subject_loss: 0.1950 - Softmax-Output_loss: 0.0382 - Output-Subject_accuracy: 0.9423 - Softmax-Output_accuracy: 0.9888 - lr: 0.0010
# Epoch 7/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0664 - Output-Subject_loss: 0.1524 - Softmax-Output_loss: 0.0449 - Output-Subject_accuracy: 0.9570 - Softmax-Output_accuracy: 0.9867 - lr: 0.0010
# Epoch 8/10
# 175/175 [==============================] - 28s 161ms/step - loss: 0.0548 - Output-Subject_loss: 0.1335 - Softmax-Output_loss: 0.0351 - Output-Subject_accuracy: 0.9631 - Softmax-Output_accuracy: 0.9904 - lr: 0.0010
# Epoch 9/10
# 175/175 [==============================] - 28s 161ms/step - loss: 0.0364 - Output-Subject_loss: 0.0956 - Softmax-Output_loss: 0.0217 - Output-Subject_accuracy: 0.9734 - Softmax-Output_accuracy: 0.9940 - lr: 0.0010
# Epoch 10/10
# 175/175 [==============================] - 28s 161ms/step - loss: 0.0308 - Output-Subject_loss: 0.0759 - Softmax-Output_loss: 0.0196 - Output-Subject_accuracy: 0.9784 - Softmax-Output_accuracy: 0.9945 - lr: 0.0010
# Position Test accuracy: 80.33 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 1- finished!
# -----------------
# Epoch 1/10
# 176/176 [==============================] - 33s 178ms/step - loss: 1.0439 - Output-Subject_loss: 2.2101 - Softmax-Output_loss: 0.7524 - Output-Subject_accuracy: 0.2557 - Softmax-Output_accuracy: 0.7630 - lr: 0.0010
# Epoch 2/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.3448 - Output-Subject_loss: 1.0672 - Softmax-Output_loss: 0.1643 - Output-Subject_accuracy: 0.6587 - Softmax-Output_accuracy: 0.9511 - lr: 0.0010
# Epoch 3/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.1728 - Output-Subject_loss: 0.5069 - Softmax-Output_loss: 0.0893 - Output-Subject_accuracy: 0.8520 - Softmax-Output_accuracy: 0.9725 - lr: 0.0010
# Epoch 4/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.1103 - Output-Subject_loss: 0.3095 - Softmax-Output_loss: 0.0605 - Output-Subject_accuracy: 0.9087 - Softmax-Output_accuracy: 0.9826 - lr: 0.0010
# Epoch 5/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.0818 - Output-Subject_loss: 0.2132 - Softmax-Output_loss: 0.0490 - Output-Subject_accuracy: 0.9361 - Softmax-Output_accuracy: 0.9850 - lr: 0.0010
# Epoch 6/10
# 176/176 [==============================] - 28s 162ms/step - loss: 0.0608 - Output-Subject_loss: 0.1543 - Softmax-Output_loss: 0.0375 - Output-Subject_accuracy: 0.9553 - Softmax-Output_accuracy: 0.9888 - lr: 0.0010
# Epoch 7/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.0373 - Output-Subject_loss: 0.1068 - Softmax-Output_loss: 0.0199 - Output-Subject_accuracy: 0.9680 - Softmax-Output_accuracy: 0.9936 - lr: 0.0010
# Epoch 8/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.0531 - Output-Subject_loss: 0.1125 - Softmax-Output_loss: 0.0382 - Output-Subject_accuracy: 0.9680 - Softmax-Output_accuracy: 0.9893 - lr: 0.0010
# Epoch 9/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.0272 - Output-Subject_loss: 0.0614 - Softmax-Output_loss: 0.0186 - Output-Subject_accuracy: 0.9812 - Softmax-Output_accuracy: 0.9944 - lr: 0.0010
# Epoch 10/10
# 176/176 [==============================] - 29s 162ms/step - loss: 0.0273 - Output-Subject_loss: 0.0566 - Softmax-Output_loss: 0.0200 - Output-Subject_accuracy: 0.9826 - Softmax-Output_accuracy: 0.9936 - lr: 0.0010
# Position Test accuracy: 71.78 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 2- finished!
# -----------------
# Epoch 1/10
# 175/175 [==============================] - 33s 180ms/step - loss: 1.0477 - Output-Subject_loss: 2.0746 - Softmax-Output_loss: 0.7910 - Output-Subject_accuracy: 0.3068 - Softmax-Output_accuracy: 0.7505 - lr: 0.0010
# Epoch 2/10
# 175/175 [==============================] - 29s 168ms/step - loss: 0.3072 - Output-Subject_loss: 0.8673 - Softmax-Output_loss: 0.1672 - Output-Subject_accuracy: 0.7367 - Softmax-Output_accuracy: 0.9448 - lr: 0.0010
# Epoch 3/10
# 175/175 [==============================] - 29s 163ms/step - loss: 0.1624 - Output-Subject_loss: 0.4261 - Softmax-Output_loss: 0.0964 - Output-Subject_accuracy: 0.8806 - Softmax-Output_accuracy: 0.9698 - lr: 0.0010
# Epoch 4/10
# 175/175 [==============================] - 28s 163ms/step - loss: 0.1048 - Output-Subject_loss: 0.2699 - Softmax-Output_loss: 0.0635 - Output-Subject_accuracy: 0.9224 - Softmax-Output_accuracy: 0.9790 - lr: 0.0010
# Epoch 5/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0666 - Output-Subject_loss: 0.1702 - Softmax-Output_loss: 0.0407 - Output-Subject_accuracy: 0.9479 - Softmax-Output_accuracy: 0.9868 - lr: 0.0010
# Epoch 6/10
# 175/175 [==============================] - 29s 163ms/step - loss: 0.0684 - Output-Subject_loss: 0.1518 - Softmax-Output_loss: 0.0476 - Output-Subject_accuracy: 0.9555 - Softmax-Output_accuracy: 0.9852 - lr: 0.0010
# Epoch 7/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0450 - Output-Subject_loss: 0.1108 - Softmax-Output_loss: 0.0286 - Output-Subject_accuracy: 0.9677 - Softmax-Output_accuracy: 0.9920 - lr: 0.0010
# Epoch 8/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0404 - Output-Subject_loss: 0.0892 - Softmax-Output_loss: 0.0282 - Output-Subject_accuracy: 0.9749 - Softmax-Output_accuracy: 0.9918 - lr: 0.0010
# Epoch 9/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0332 - Output-Subject_loss: 0.0716 - Softmax-Output_loss: 0.0235 - Output-Subject_accuracy: 0.9787 - Softmax-Output_accuracy: 0.9924 - lr: 0.0010
# Epoch 10/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0319 - Output-Subject_loss: 0.0664 - Softmax-Output_loss: 0.0232 - Output-Subject_accuracy: 0.9817 - Softmax-Output_accuracy: 0.9929 - lr: 0.0010
# Position Test accuracy: 99.6 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 3- finished!
# -----------------
# Epoch 1/10
# 175/175 [==============================] - 34s 186ms/step - loss: 1.1377 - Output-Subject_loss: 2.3028 - Softmax-Output_loss: 0.8464 - Output-Subject_accuracy: 0.2179 - Softmax-Output_accuracy: 0.7392 - lr: 0.0010
# Epoch 2/10
# 175/175 [==============================] - 29s 163ms/step - loss: 0.3850 - Output-Subject_loss: 1.2299 - Softmax-Output_loss: 0.1738 - Output-Subject_accuracy: 0.5919 - Softmax-Output_accuracy: 0.9476 - lr: 0.0010
# Epoch 3/10
# 175/175 [==============================] - 28s 161ms/step - loss: 0.1999 - Output-Subject_loss: 0.5687 - Softmax-Output_loss: 0.1077 - Output-Subject_accuracy: 0.8292 - Softmax-Output_accuracy: 0.9673 - lr: 0.0010
# Epoch 4/10
# 175/175 [==============================] - 28s 163ms/step - loss: 0.1235 - Output-Subject_loss: 0.3347 - Softmax-Output_loss: 0.0707 - Output-Subject_accuracy: 0.9051 - Softmax-Output_accuracy: 0.9783 - lr: 0.0010
# Epoch 5/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0906 - Output-Subject_loss: 0.2519 - Softmax-Output_loss: 0.0503 - Output-Subject_accuracy: 0.9271 - Softmax-Output_accuracy: 0.9840 - lr: 0.0010
# Epoch 6/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0592 - Output-Subject_loss: 0.1659 - Softmax-Output_loss: 0.0325 - Output-Subject_accuracy: 0.9502 - Softmax-Output_accuracy: 0.9893 - lr: 0.0010
# Epoch 7/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0513 - Output-Subject_loss: 0.1360 - Softmax-Output_loss: 0.0301 - Output-Subject_accuracy: 0.9590 - Softmax-Output_accuracy: 0.9910 - lr: 0.0010
# Epoch 8/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0555 - Output-Subject_loss: 0.1229 - Softmax-Output_loss: 0.0387 - Output-Subject_accuracy: 0.9628 - Softmax-Output_accuracy: 0.9884 - lr: 0.0010
# Epoch 9/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0321 - Output-Subject_loss: 0.0759 - Softmax-Output_loss: 0.0212 - Output-Subject_accuracy: 0.9783 - Softmax-Output_accuracy: 0.9937 - lr: 0.0010
# Epoch 10/10
# 175/175 [==============================] - 28s 162ms/step - loss: 0.0333 - Output-Subject_loss: 0.0736 - Softmax-Output_loss: 0.0232 - Output-Subject_accuracy: 0.9782 - Softmax-Output_accuracy: 0.9927 - lr: 0.0010
# Position Test accuracy: 88.49 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 4- finished!
# -----------------
# Epoch 1/10
# 168/168 [==============================] - 31s 172ms/step - loss: 1.0704 - Output-Subject_loss: 2.1071 - Softmax-Output_loss: 0.8112 - Output-Subject_accuracy: 0.3051 - Softmax-Output_accuracy: 0.7472 - lr: 0.0010
# Epoch 2/10
# 168/168 [==============================] - 28s 167ms/step - loss: 0.3130 - Output-Subject_loss: 0.8553 - Softmax-Output_loss: 0.1775 - Output-Subject_accuracy: 0.7385 - Softmax-Output_accuracy: 0.9441 - lr: 0.0010
# Epoch 3/10
# 168/168 [==============================] - 27s 161ms/step - loss: 0.1473 - Output-Subject_loss: 0.3722 - Softmax-Output_loss: 0.0911 - Output-Subject_accuracy: 0.8975 - Softmax-Output_accuracy: 0.9720 - lr: 0.0010
# Epoch 4/10
# 168/168 [==============================] - 27s 163ms/step - loss: 0.0939 - Output-Subject_loss: 0.2278 - Softmax-Output_loss: 0.0605 - Output-Subject_accuracy: 0.9360 - Softmax-Output_accuracy: 0.9825 - lr: 0.0010
# Epoch 5/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0670 - Output-Subject_loss: 0.1485 - Softmax-Output_loss: 0.0466 - Output-Subject_accuracy: 0.9572 - Softmax-Output_accuracy: 0.9869 - lr: 0.0010
# Epoch 6/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0520 - Output-Subject_loss: 0.1095 - Softmax-Output_loss: 0.0376 - Output-Subject_accuracy: 0.9691 - Softmax-Output_accuracy: 0.9889 - lr: 0.0010
# Epoch 7/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0425 - Output-Subject_loss: 0.0900 - Softmax-Output_loss: 0.0306 - Output-Subject_accuracy: 0.9733 - Softmax-Output_accuracy: 0.9910 - lr: 0.0010
# Epoch 8/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0315 - Output-Subject_loss: 0.0631 - Softmax-Output_loss: 0.0236 - Output-Subject_accuracy: 0.9807 - Softmax-Output_accuracy: 0.9925 - lr: 0.0010
# Epoch 9/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0255 - Output-Subject_loss: 0.0553 - Softmax-Output_loss: 0.0181 - Output-Subject_accuracy: 0.9844 - Softmax-Output_accuracy: 0.9946 - lr: 0.0010
# Epoch 10/10
# 168/168 [==============================] - 27s 161ms/step - loss: 0.0315 - Output-Subject_loss: 0.0545 - Softmax-Output_loss: 0.0258 - Output-Subject_accuracy: 0.9843 - Softmax-Output_accuracy: 0.9924 - lr: 0.0010
# Position Test accuracy: 82.13 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 5- finished!
# -----------------
# Epoch 1/10
# 176/176 [==============================] - 31s 168ms/step - loss: 1.0399 - Output-Subject_loss: 2.1119 - Softmax-Output_loss: 0.7719 - Output-Subject_accuracy: 0.3032 - Softmax-Output_accuracy: 0.7600 - lr: 0.0010
# Epoch 2/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.2965 - Output-Subject_loss: 0.8716 - Softmax-Output_loss: 0.1527 - Output-Subject_accuracy: 0.7431 - Softmax-Output_accuracy: 0.9523 - lr: 0.0010
# Epoch 3/10
# 176/176 [==============================] - 28s 161ms/step - loss: 0.1513 - Output-Subject_loss: 0.4085 - Softmax-Output_loss: 0.0870 - Output-Subject_accuracy: 0.8866 - Softmax-Output_accuracy: 0.9737 - lr: 0.0010
# Epoch 4/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.0978 - Output-Subject_loss: 0.2542 - Softmax-Output_loss: 0.0586 - Output-Subject_accuracy: 0.9289 - Softmax-Output_accuracy: 0.9813 - lr: 0.0010
# Epoch 5/10
# 176/176 [==============================] - 28s 162ms/step - loss: 0.0773 - Output-Subject_loss: 0.1909 - Softmax-Output_loss: 0.0489 - Output-Subject_accuracy: 0.9452 - Softmax-Output_accuracy: 0.9846 - lr: 0.0010
# Epoch 6/10
# 176/176 [==============================] - 28s 162ms/step - loss: 0.0527 - Output-Subject_loss: 0.1303 - Softmax-Output_loss: 0.0333 - Output-Subject_accuracy: 0.9636 - Softmax-Output_accuracy: 0.9906 - lr: 0.0010
# Epoch 7/10
# 176/176 [==============================] - 28s 162ms/step - loss: 0.0449 - Output-Subject_loss: 0.0987 - Softmax-Output_loss: 0.0314 - Output-Subject_accuracy: 0.9716 - Softmax-Output_accuracy: 0.9895 - lr: 0.0010
# Epoch 8/10
# 176/176 [==============================] - 28s 162ms/step - loss: 0.0329 - Output-Subject_loss: 0.0739 - Softmax-Output_loss: 0.0227 - Output-Subject_accuracy: 0.9791 - Softmax-Output_accuracy: 0.9937 - lr: 0.0010
# Epoch 9/10
# 176/176 [==============================] - 28s 162ms/step - loss: 0.0486 - Output-Subject_loss: 0.0819 - Softmax-Output_loss: 0.0403 - Output-Subject_accuracy: 0.9764 - Softmax-Output_accuracy: 0.9892 - lr: 0.0010
# Epoch 10/10
# 176/176 [==============================] - 28s 162ms/step - loss: 0.0315 - Output-Subject_loss: 0.0684 - Softmax-Output_loss: 0.0223 - Output-Subject_accuracy: 0.9808 - Softmax-Output_accuracy: 0.9939 - lr: 0.0010
# Position Test accuracy: 84.55 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 6- finished!
# -----------------
# Epoch 1/10
# 164/164 [==============================] - 32s 185ms/step - loss: 1.1515 - Output-Subject_loss: 2.2788 - Softmax-Output_loss: 0.8697 - Output-Subject_accuracy: 0.2292 - Softmax-Output_accuracy: 0.7279 - lr: 0.0010
# Epoch 2/10
# 164/164 [==============================] - 27s 163ms/step - loss: 0.3681 - Output-Subject_loss: 1.0435 - Softmax-Output_loss: 0.1993 - Output-Subject_accuracy: 0.6865 - Softmax-Output_accuracy: 0.9381 - lr: 0.0010
# Epoch 3/10
# 164/164 [==============================] - 27s 162ms/step - loss: 0.1825 - Output-Subject_loss: 0.5013 - Softmax-Output_loss: 0.1027 - Output-Subject_accuracy: 0.8616 - Softmax-Output_accuracy: 0.9663 - lr: 0.0010
# Epoch 4/10
# 164/164 [==============================] - 27s 163ms/step - loss: 0.1231 - Output-Subject_loss: 0.3091 - Softmax-Output_loss: 0.0766 - Output-Subject_accuracy: 0.9137 - Softmax-Output_accuracy: 0.9765 - lr: 0.0010
# Epoch 5/10
# 164/164 [==============================] - 27s 163ms/step - loss: 0.0961 - Output-Subject_loss: 0.2204 - Softmax-Output_loss: 0.0650 - Output-Subject_accuracy: 0.9340 - Softmax-Output_accuracy: 0.9791 - lr: 0.0010
# Epoch 6/10
# 164/164 [==============================] - 27s 162ms/step - loss: 0.0706 - Output-Subject_loss: 0.1684 - Softmax-Output_loss: 0.0461 - Output-Subject_accuracy: 0.9513 - Softmax-Output_accuracy: 0.9861 - lr: 0.0010
# Epoch 7/10
# 164/164 [==============================] - 27s 162ms/step - loss: 0.0475 - Output-Subject_loss: 0.1338 - Softmax-Output_loss: 0.0259 - Output-Subject_accuracy: 0.9607 - Softmax-Output_accuracy: 0.9917 - lr: 0.0010
# Epoch 8/10
# 164/164 [==============================] - 27s 162ms/step - loss: 0.0519 - Output-Subject_loss: 0.1125 - Softmax-Output_loss: 0.0368 - Output-Subject_accuracy: 0.9677 - Softmax-Output_accuracy: 0.9892 - lr: 0.0010
# Epoch 9/10
# 164/164 [==============================] - 27s 162ms/step - loss: 0.0370 - Output-Subject_loss: 0.0784 - Softmax-Output_loss: 0.0267 - Output-Subject_accuracy: 0.9770 - Softmax-Output_accuracy: 0.9913 - lr: 0.0010
# Epoch 10/10
# 164/164 [==============================] - 27s 162ms/step - loss: 0.0377 - Output-Subject_loss: 0.0742 - Softmax-Output_loss: 0.0285 - Output-Subject_accuracy: 0.9788 - Softmax-Output_accuracy: 0.9922 - lr: 0.0010
# Position Test accuracy: 93.86 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 7- finished!
# -----------------
# Epoch 1/10
# 168/168 [==============================] - 31s 176ms/step - loss: 1.1477 - Output-Subject_loss: 2.2579 - Softmax-Output_loss: 0.8701 - Output-Subject_accuracy: 0.2463 - Softmax-Output_accuracy: 0.7342 - lr: 0.0010
# Epoch 2/10
# 168/168 [==============================] - 27s 163ms/step - loss: 0.3806 - Output-Subject_loss: 1.2314 - Softmax-Output_loss: 0.1679 - Output-Subject_accuracy: 0.5957 - Softmax-Output_accuracy: 0.9477 - lr: 0.0010
# Epoch 3/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.2120 - Output-Subject_loss: 0.6420 - Softmax-Output_loss: 0.1045 - Output-Subject_accuracy: 0.8101 - Softmax-Output_accuracy: 0.9685 - lr: 0.0010
# Epoch 4/10
# 168/168 [==============================] - 27s 163ms/step - loss: 0.1238 - Output-Subject_loss: 0.3629 - Softmax-Output_loss: 0.0640 - Output-Subject_accuracy: 0.8970 - Softmax-Output_accuracy: 0.9806 - lr: 0.0010
# Epoch 5/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0896 - Output-Subject_loss: 0.2464 - Softmax-Output_loss: 0.0504 - Output-Subject_accuracy: 0.9313 - Softmax-Output_accuracy: 0.9836 - lr: 0.0010
# Epoch 6/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0629 - Output-Subject_loss: 0.1774 - Softmax-Output_loss: 0.0343 - Output-Subject_accuracy: 0.9494 - Softmax-Output_accuracy: 0.9896 - lr: 0.0010
# Epoch 7/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0578 - Output-Subject_loss: 0.1536 - Softmax-Output_loss: 0.0339 - Output-Subject_accuracy: 0.9545 - Softmax-Output_accuracy: 0.9894 - lr: 0.0010
# Epoch 8/10
# 168/168 [==============================] - 27s 163ms/step - loss: 0.0442 - Output-Subject_loss: 0.1162 - Softmax-Output_loss: 0.0262 - Output-Subject_accuracy: 0.9666 - Softmax-Output_accuracy: 0.9915 - lr: 0.0010
# Epoch 9/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0351 - Output-Subject_loss: 0.0940 - Softmax-Output_loss: 0.0204 - Output-Subject_accuracy: 0.9729 - Softmax-Output_accuracy: 0.9934 - lr: 0.0010
# Epoch 10/10
# 168/168 [==============================] - 27s 162ms/step - loss: 0.0346 - Output-Subject_loss: 0.0832 - Softmax-Output_loss: 0.0225 - Output-Subject_accuracy: 0.9754 - Softmax-Output_accuracy: 0.9943 - lr: 0.0010
# Position Test accuracy: 86.86 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 8- finished!
# -----------------
# Epoch 1/10
# 176/176 [==============================] - 33s 180ms/step - loss: 1.0628 - Output-Subject_loss: 2.1106 - Softmax-Output_loss: 0.8008 - Output-Subject_accuracy: 0.3099 - Softmax-Output_accuracy: 0.7563 - lr: 0.0010
# Epoch 2/10
# 176/176 [==============================] - 29s 165ms/step - loss: 0.3198 - Output-Subject_loss: 0.8983 - Softmax-Output_loss: 0.1752 - Output-Subject_accuracy: 0.7285 - Softmax-Output_accuracy: 0.9457 - lr: 0.0010
# Epoch 3/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.1648 - Output-Subject_loss: 0.4564 - Softmax-Output_loss: 0.0919 - Output-Subject_accuracy: 0.8728 - Softmax-Output_accuracy: 0.9712 - lr: 0.0010
# Epoch 4/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.1059 - Output-Subject_loss: 0.2966 - Softmax-Output_loss: 0.0582 - Output-Subject_accuracy: 0.9147 - Softmax-Output_accuracy: 0.9821 - lr: 0.0010
# Epoch 5/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.0818 - Output-Subject_loss: 0.2163 - Softmax-Output_loss: 0.0482 - Output-Subject_accuracy: 0.9370 - Softmax-Output_accuracy: 0.9855 - lr: 0.0010
# Epoch 6/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.0589 - Output-Subject_loss: 0.1494 - Softmax-Output_loss: 0.0362 - Output-Subject_accuracy: 0.9553 - Softmax-Output_accuracy: 0.9889 - lr: 0.0010
# Epoch 7/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.0538 - Output-Subject_loss: 0.1400 - Softmax-Output_loss: 0.0323 - Output-Subject_accuracy: 0.9581 - Softmax-Output_accuracy: 0.9898 - lr: 0.0010
# Epoch 8/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.0459 - Output-Subject_loss: 0.1115 - Softmax-Output_loss: 0.0295 - Output-Subject_accuracy: 0.9667 - Softmax-Output_accuracy: 0.9916 - lr: 0.0010
# Epoch 9/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.0398 - Output-Subject_loss: 0.0886 - Softmax-Output_loss: 0.0276 - Output-Subject_accuracy: 0.9735 - Softmax-Output_accuracy: 0.9912 - lr: 0.0010
# Epoch 10/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.0298 - Output-Subject_loss: 0.0706 - Softmax-Output_loss: 0.0196 - Output-Subject_accuracy: 0.9797 - Softmax-Output_accuracy: 0.9936 - lr: 0.0010
# Position Test accuracy: 82.67 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 9- finished!
# -----------------
# Epoch 1/10
# 175/175 [==============================] - 33s 181ms/step - loss: 1.0931 - Output-Subject_loss: 2.0862 - Softmax-Output_loss: 0.8448 - Output-Subject_accuracy: 0.2998 - Softmax-Output_accuracy: 0.7395 - lr: 0.0010
# Epoch 2/10
# 175/175 [==============================] - 29s 165ms/step - loss: 0.3087 - Output-Subject_loss: 0.8538 - Softmax-Output_loss: 0.1724 - Output-Subject_accuracy: 0.7415 - Softmax-Output_accuracy: 0.9449 - lr: 0.0010
# Epoch 3/10
# 175/175 [==============================] - 29s 163ms/step - loss: 0.1562 - Output-Subject_loss: 0.4043 - Softmax-Output_loss: 0.0942 - Output-Subject_accuracy: 0.8834 - Softmax-Output_accuracy: 0.9703 - lr: 0.0010
# Epoch 4/10
# 175/175 [==============================] - 29s 165ms/step - loss: 0.0971 - Output-Subject_loss: 0.2519 - Softmax-Output_loss: 0.0584 - Output-Subject_accuracy: 0.9253 - Softmax-Output_accuracy: 0.9807 - lr: 0.0010
# Epoch 5/10
# 175/175 [==============================] - 29s 164ms/step - loss: 0.0856 - Output-Subject_loss: 0.2050 - Softmax-Output_loss: 0.0558 - Output-Subject_accuracy: 0.9408 - Softmax-Output_accuracy: 0.9832 - lr: 0.0010
# Epoch 6/10
# 175/175 [==============================] - 29s 163ms/step - loss: 0.0478 - Output-Subject_loss: 0.1174 - Softmax-Output_loss: 0.0304 - Output-Subject_accuracy: 0.9648 - Softmax-Output_accuracy: 0.9912 - lr: 0.0010
# Epoch 7/10
# 175/175 [==============================] - 29s 164ms/step - loss: 0.0431 - Output-Subject_loss: 0.0951 - Softmax-Output_loss: 0.0301 - Output-Subject_accuracy: 0.9717 - Softmax-Output_accuracy: 0.9901 - lr: 0.0010
# Epoch 8/10
# 175/175 [==============================] - 29s 164ms/step - loss: 0.0371 - Output-Subject_loss: 0.0764 - Softmax-Output_loss: 0.0273 - Output-Subject_accuracy: 0.9773 - Softmax-Output_accuracy: 0.9923 - lr: 0.0010
# Epoch 9/10
# 175/175 [==============================] - 29s 163ms/step - loss: 0.0385 - Output-Subject_loss: 0.0800 - Softmax-Output_loss: 0.0281 - Output-Subject_accuracy: 0.9777 - Softmax-Output_accuracy: 0.9913 - lr: 0.0010
# Epoch 10/10
# 175/175 [==============================] - 29s 164ms/step - loss: 0.0288 - Output-Subject_loss: 0.0590 - Softmax-Output_loss: 0.0212 - Output-Subject_accuracy: 0.9821 - Softmax-Output_accuracy: 0.9940 - lr: 0.0010
# Position Test accuracy: 98.54 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 10- finished!
# -----------------
# Epoch 1/10
# 176/176 [==============================] - 32s 173ms/step - loss: 1.0157 - Output-Subject_loss: 2.0665 - Softmax-Output_loss: 0.7530 - Output-Subject_accuracy: 0.2909 - Softmax-Output_accuracy: 0.7627 - lr: 0.0010
# Epoch 2/10
# 176/176 [==============================] - 29s 165ms/step - loss: 0.3050 - Output-Subject_loss: 0.8426 - Softmax-Output_loss: 0.1706 - Output-Subject_accuracy: 0.7391 - Softmax-Output_accuracy: 0.9471 - lr: 0.0010
# Epoch 3/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.1586 - Output-Subject_loss: 0.3936 - Softmax-Output_loss: 0.0998 - Output-Subject_accuracy: 0.8871 - Softmax-Output_accuracy: 0.9710 - lr: 0.0010
# Epoch 4/10
# 176/176 [==============================] - 29s 165ms/step - loss: 0.1046 - Output-Subject_loss: 0.2383 - Softmax-Output_loss: 0.0711 - Output-Subject_accuracy: 0.9310 - Softmax-Output_accuracy: 0.9783 - lr: 0.0010
# Epoch 5/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.0688 - Output-Subject_loss: 0.1499 - Softmax-Output_loss: 0.0485 - Output-Subject_accuracy: 0.9570 - Softmax-Output_accuracy: 0.9848 - lr: 0.0010
# Epoch 6/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.0419 - Output-Subject_loss: 0.0929 - Softmax-Output_loss: 0.0292 - Output-Subject_accuracy: 0.9739 - Softmax-Output_accuracy: 0.9912 - lr: 0.0010
# Epoch 7/10
# 176/176 [==============================] - 29s 164ms/step - loss: 0.0405 - Output-Subject_loss: 0.0781 - Softmax-Output_loss: 0.0311 - Output-Subject_accuracy: 0.9778 - Softmax-Output_accuracy: 0.9902 - lr: 0.0010
# Epoch 8/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.0398 - Output-Subject_loss: 0.0638 - Softmax-Output_loss: 0.0338 - Output-Subject_accuracy: 0.9834 - Softmax-Output_accuracy: 0.9900 - lr: 0.0010
# Epoch 9/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.0373 - Output-Subject_loss: 0.0581 - Softmax-Output_loss: 0.0320 - Output-Subject_accuracy: 0.9827 - Softmax-Output_accuracy: 0.9914 - lr: 0.0010
# Epoch 10/10
# 176/176 [==============================] - 29s 163ms/step - loss: 0.0229 - Output-Subject_loss: 0.0424 - Softmax-Output_loss: 0.0180 - Output-Subject_accuracy: 0.9867 - Softmax-Output_accuracy: 0.9953 - lr: 0.0010
# Position Test accuracy: 94.78 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 11- finished!
# -----------------
# Epoch 1/10
# 168/168 [==============================] - 34s 189ms/step - loss: 1.1117 - Output-Subject_loss: 1.9949 - Softmax-Output_loss: 0.8909 - Output-Subject_accuracy: 0.3306 - Softmax-Output_accuracy: 0.7287 - lr: 0.0010
# Epoch 2/10
# 168/168 [==============================] - 28s 164ms/step - loss: 0.3062 - Output-Subject_loss: 0.8422 - Softmax-Output_loss: 0.1722 - Output-Subject_accuracy: 0.7403 - Softmax-Output_accuracy: 0.9463 - lr: 0.0010
# Epoch 3/10
# 168/168 [==============================] - 28s 165ms/step - loss: 0.1557 - Output-Subject_loss: 0.4120 - Softmax-Output_loss: 0.0916 - Output-Subject_accuracy: 0.8819 - Softmax-Output_accuracy: 0.9706 - lr: 0.0010
# Epoch 4/10
# 168/168 [==============================] - 28s 164ms/step - loss: 0.1138 - Output-Subject_loss: 0.2638 - Softmax-Output_loss: 0.0763 - Output-Subject_accuracy: 0.9227 - Softmax-Output_accuracy: 0.9753 - lr: 0.0010
# Epoch 5/10
# 168/168 [==============================] - 28s 165ms/step - loss: 0.0675 - Output-Subject_loss: 0.1822 - Softmax-Output_loss: 0.0388 - Output-Subject_accuracy: 0.9454 - Softmax-Output_accuracy: 0.9880 - lr: 0.0010
# Epoch 6/10
# 168/168 [==============================] - 28s 165ms/step - loss: 0.0568 - Output-Subject_loss: 0.1263 - Softmax-Output_loss: 0.0394 - Output-Subject_accuracy: 0.9640 - Softmax-Output_accuracy: 0.9877 - lr: 0.0010
# Epoch 7/10
# 168/168 [==============================] - 28s 165ms/step - loss: 0.0530 - Output-Subject_loss: 0.1211 - Softmax-Output_loss: 0.0359 - Output-Subject_accuracy: 0.9640 - Softmax-Output_accuracy: 0.9881 - lr: 0.0010
# Epoch 8/10
# 168/168 [==============================] - 28s 165ms/step - loss: 0.0412 - Output-Subject_loss: 0.1013 - Softmax-Output_loss: 0.0262 - Output-Subject_accuracy: 0.9724 - Softmax-Output_accuracy: 0.9909 - lr: 0.0010
# Epoch 9/10
# 168/168 [==============================] - 28s 165ms/step - loss: 0.0323 - Output-Subject_loss: 0.0719 - Softmax-Output_loss: 0.0224 - Output-Subject_accuracy: 0.9793 - Softmax-Output_accuracy: 0.9938 - lr: 0.0010
# Epoch 10/10
# 168/168 [==============================] - 28s 165ms/step - loss: 0.0292 - Output-Subject_loss: 0.0652 - Softmax-Output_loss: 0.0202 - Output-Subject_accuracy: 0.9803 - Softmax-Output_accuracy: 0.9943 - lr: 0.0010
# Position Test accuracy: 94.2 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 12- finished!
# -----------------
# Epoch 1/10
# 177/177 [==============================] - 33s 176ms/step - loss: 1.0890 - Output-Subject_loss: 2.1199 - Softmax-Output_loss: 0.8313 - Output-Subject_accuracy: 0.2761 - Softmax-Output_accuracy: 0.7488 - lr: 0.0010
# Epoch 2/10
# 177/177 [==============================] - 29s 165ms/step - loss: 0.3525 - Output-Subject_loss: 1.0306 - Softmax-Output_loss: 0.1830 - Output-Subject_accuracy: 0.6764 - Softmax-Output_accuracy: 0.9455 - lr: 0.0010
# Epoch 3/10
# 177/177 [==============================] - 29s 164ms/step - loss: 0.1820 - Output-Subject_loss: 0.5013 - Softmax-Output_loss: 0.1022 - Output-Subject_accuracy: 0.8543 - Softmax-Output_accuracy: 0.9693 - lr: 0.0010
# Epoch 4/10
# 177/177 [==============================] - 29s 165ms/step - loss: 0.1154 - Output-Subject_loss: 0.3102 - Softmax-Output_loss: 0.0668 - Output-Subject_accuracy: 0.9118 - Softmax-Output_accuracy: 0.9791 - lr: 0.0010
# Epoch 5/10
# 177/177 [==============================] - 29s 165ms/step - loss: 0.0861 - Output-Subject_loss: 0.2186 - Softmax-Output_loss: 0.0530 - Output-Subject_accuracy: 0.9367 - Softmax-Output_accuracy: 0.9842 - lr: 0.0010
# Epoch 6/10
# 177/177 [==============================] - 29s 164ms/step - loss: 0.0600 - Output-Subject_loss: 0.1578 - Softmax-Output_loss: 0.0355 - Output-Subject_accuracy: 0.9552 - Softmax-Output_accuracy: 0.9893 - lr: 0.0010
# Epoch 7/10
# 177/177 [==============================] - 29s 164ms/step - loss: 0.0607 - Output-Subject_loss: 0.1408 - Softmax-Output_loss: 0.0407 - Output-Subject_accuracy: 0.9596 - Softmax-Output_accuracy: 0.9880 - lr: 0.0010
# Epoch 8/10
# 177/177 [==============================] - 29s 164ms/step - loss: 0.0497 - Output-Subject_loss: 0.1175 - Softmax-Output_loss: 0.0327 - Output-Subject_accuracy: 0.9663 - Softmax-Output_accuracy: 0.9910 - lr: 0.0010
# Epoch 9/10
# 177/177 [==============================] - 29s 164ms/step - loss: 0.0380 - Output-Subject_loss: 0.0877 - Softmax-Output_loss: 0.0256 - Output-Subject_accuracy: 0.9741 - Softmax-Output_accuracy: 0.9926 - lr: 0.0010
# Epoch 10/10
# 177/177 [==============================] - 29s 164ms/step - loss: 0.0306 - Output-Subject_loss: 0.0714 - Softmax-Output_loss: 0.0204 - Output-Subject_accuracy: 0.9802 - Softmax-Output_accuracy: 0.9938 - lr: 0.0010
# Position Test accuracy: 82.35 %
# Subject Test accuracy: 0.0 %
# ---------------------
# ---------------------
# 13- finished!
# -----------------
# -----------------
# Average KFold Position Accuracy: 87.7 %
# Standard deviation Position: 7.81 %

# %%
df = pd.DataFrame(matrix_pos_)
df.columns = [1,8,9,10,11,12,15,16,17,2,4,5,13,3,6,7,14]
df = df.rename(columns={1:'Supine',8:'Supine Star',9:'Supine Hand Crossed',10:'Supine Knees Up',
                   11:'Supine Right Knee Up',12:'Supine Left Knee Up',15:'Supine 30° Bed Inclination',16:'Supine 45° Bed Inclination',
                   17:'Supine 60° Bed Inclination',2:'Right',4:'Right 30° Body Roll',5:'Right 60° Body Roll',13:'Right Fetus',
                  3:'Left',6:'Left 30° Body Roll',7:'Left 60° Body Roll',14:'Left Fetus'})

#normalization
row_sums = matrix_sub_.sum(axis=1)
matrix_sub_norm = matrix_sub_ / row_sums[:, np.newaxis]
row_sums = matrix_pos_.sum(axis=1)
matrix_pos_norm = matrix_pos_ / row_sums[:, np.newaxis]

label_sub = [str('Subject: ')+str(i) for i in range(1,14)]

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(17,8)) 

sns.heatmap(matrix_pos_norm, annot=matrix_pos_,xticklabels=list(df.columns), yticklabels=list(df.columns),
            fmt="g",cmap='Blues',ax=ax1,vmin=0, vmax=1,square=True, annot_kws={"fontsize":7})
ax1.hlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([9, 13],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([0],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.hlines([17],*ax1.get_xlim(), color='black',lw=2)
ax1.vlines([0],*ax1.get_xlim(), color='black',lw=2)

sns.heatmap(matrix_sub_norm, annot=matrix_sub_,xticklabels=label_sub, yticklabels=label_sub,
            fmt="g",cmap='Blues',ax=ax2,vmin=0, vmax=1,square=True, annot_kws={"fontsize":4})
ax2.hlines([0],*plt.xlim(), color='black',lw=2)
ax2.vlines([13],*plt.xlim(), color='black',lw=2)
ax2.hlines([13],*plt.xlim(), color='black',lw=2)
ax2.vlines([0],*plt.xlim(), color='black',lw=2)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app
